# %%
# !pip install nsepy
# Out:
# Requirement already satisfied: nsepy in c:\users\vinis\anaconda3\lib\site-packages (0.8)
# Requirement already satisfied: click in c:\users\vinis\anaconda3\lib\site-packages (from nsepy) (8.0.3)
# Requirement already satisfied: beautifulsoup4 in c:\users\vinis\anaconda3\lib\site-packages (from nsepy) (4.10.0)
# Requirement already satisfied: lxml in c:\users\vinis\anaconda3\lib\site-packages (from nsepy) (4.6.3)
# Requirement already satisfied: six in c:\users\vinis\anaconda3\lib\site-packages (from nsepy) (1.16.0)
# Requirement already satisfied: numpy in c:\users\vinis\anaconda3\lib\site-packages (from nsepy) (1.20.3)
# Requirement already satisfied: pandas in c:\users\vinis\anaconda3\lib\site-packages (from nsepy) (1.3.4)
# Requirement already satisfied: requests in c:\users\vinis\anaconda3\lib\site-packages (from nsepy) (2.26.0)
# Requirement already satisfied: soupsieve>1.2 in c:\users\vinis\anaconda3\lib\site-packages (from beautifulsoup4->nsepy) (2.2.1)
# Requirement already satisfied: colorama in c:\users\vinis\anaconda3\lib\site-packages (from click->nsepy) (0.4.4)
# Requirement already satisfied: python-dateutil>=2.7.3 in c:\users\vinis\anaconda3\lib\site-packages (from pandas->nsepy) (2.8.2)
# Requirement already satisfied: pytz>=2017.3 in c:\users\vinis\anaconda3\lib\site-packages (from pandas->nsepy) (2021.3)
# Requirement already satisfied: charset-normalizer~=2.0.0 in c:\users\vinis\anaconda3\lib\site-packages (from requests->nsepy) (2.0.4)
# Requirement already satisfied: idna<4,>=2.5 in c:\users\vinis\anaconda3\lib\site-packages (from requests->nsepy) (3.2)
# Requirement already satisfied: certifi>=2017.4.17 in c:\users\vinis\anaconda3\lib\site-packages (from requests->nsepy) (2022.6.15)
# Requirement already satisfied: urllib3<1.27,>=1.21.1 in c:\users\vinis\anaconda3\lib\site-packages (from requests->nsepy) (1.26.7)

# %%
import pandas as pd
from datetime import date
from nsepy import get_history

# %%
import datetime
import nsepy

# %%
def getHistoricalData(stockName):
    today = datetime.date.today()
    duration = 500
    start = today + datetime.timedelta(-duration)
    
    stockData = nsepy.get_history(symbol=stockName,start=start, end=today)
    return stockData

df = getHistoricalData('RELIANCE')

# %%
df
# Out:
#               Symbol Series  Prev Close     Open    High      Low     Last  \
# Date
# 2021-04-29  RELIANCE     EQ     1997.30  2022.90  2044.5  2007.30  2020.00
# 2021-04-30  RELIANCE     EQ     2024.05  2008.50  2036.0  1987.55  1995.90
# 2021-05-03  RELIANCE     EQ     1994.50  1966.00  1979.0  1943.10  1956.00
# 2021-05-04  RELIANCE     EQ     1959.05  1950.00  1967.8  1911.00  1918.00
# 2021-05-05  RELIANCE     EQ     1916.60  1923.35  1938.5  1908.05  1921.50
# ...              ...    ...         ...      ...     ...      ...      ...
# 2022-09-05  RELIANCE     EQ     2530.50  2531.00  2581.5  2531.00  2567.15
# 2022-09-06  RELIANCE     EQ     2569.80  2573.00  2606.0  2572.00  2594.00
# 2022-09-07  RELIANCE     EQ     2596.85  2575.00  2594.9  2570.00  2580.50
# 2022-09-08  RELIANCE     EQ     2581.75  2588.25  2598.0  2571.00  2583.05
# 2022-09-09  RELIANCE     EQ     2585.40  2610.00  2610.0  2564.00  2568.90
#
#               Close     VWAP    Volume      Turnover  Trades  \
# Date
# 2021-04-29  2024.05  2024.21   8035915  1.626634e+15  213153
# 2021-04-30  1994.50  2010.20   9150974  1.839532e+15  288687
# 2021-05-03  1959.05  1958.46  10909942  2.136664e+15  343806
# 2021-05-04  1916.60  1935.83  10083693  1.952033e+15  325798
# 2021-05-05  1920.10  1923.26   5719649  1.100036e+15  190990
# ...             ...      ...       ...           ...     ...
# 2022-09-05  2569.80  2563.92   5227785  1.340362e+15  189614
# 2022-09-06  2596.85  2592.68   5030172  1.304165e+15  174426
# 2022-09-07  2581.75  2580.95   3455942  8.919602e+14  117855
# 2022-09-08  2585.40  2583.54   3256840  8.414188e+14  116529
# 2022-09-09  2569.30  2577.69   3837302  9.891380e+14  185947
#
#             Deliverable Volume  %Deliverble
# Date
# 2021-04-29             2834103       0.3527
# 2021-04-30             3902504       0.4265
# 2021-05-03             3800598       0.3484
# 2021-05-04             4435071       0.4398
# 2021-05-05             1762417       0.3081
# ...                        ...          ...
# 2022-09-05             2658456       0.5085
# 2022-09-06             2588620       0.5146
# 2022-09-07             1724115       0.4989
# 2022-09-08             1821103       0.5592
# 2022-09-09             2149444       0.5601
#
# [341 rows x 14 columns]

# %%
df.to_csv('Relience.csv')

# %%
# !pip install pandas-profiling
# Out:
# Collecting pandas-profiling
#   Downloading pandas_profiling-3.3.0-py2.py3-none-any.whl (268 kB)
# Collecting statsmodels<0.14,>=0.13.2
#   Downloading statsmodels-0.13.2-cp39-cp39-win_amd64.whl (9.1 MB)
# Requirement already satisfied: requests<2.29,>=2.24.0 in c:\users\vinis\anaconda3\lib\site-packages (from pandas-profiling) (2.26.0)
# Requirement already satisfied: pandas!=1.4.0,<1.5,>1.1 in c:\users\vinis\anaconda3\lib\site-packages (from pandas-profiling) (1.3.4)
# Requirement already satisfied: PyYAML<6.1,>=5.0.0 in c:\users\vinis\anaconda3\lib\site-packages (from pandas-profiling) (6.0)
# Collecting multimethod<1.9,>=1.4
#   Downloading multimethod-1.8-py3-none-any.whl (9.8 kB)
# Requirement already satisfied: jinja2<3.2,>=2.11.1 in c:\users\vinis\anaconda3\lib\site-packages (from pandas-profiling) (2.11.3)
# Requirement already satisfied: scipy<1.10,>=1.4.1 in c:\users\vinis\anaconda3\lib\site-packages (from pandas-profiling) (1.7.1)
# Requirement already satisfied: joblib~=1.1.0 in c:\users\vinis\anaconda3\lib\site-packages (from pandas-profiling) (1.1.0)
# Requirement already satisfied: pydantic<1.10,>=1.8.1 in c:\users\vinis\anaconda3\lib\site-packages (from pandas-profiling) (1.8.2)
# Requirement already satisfied: seaborn<0.12,>=0.10.1 in c:\users\vinis\anaconda3\lib\site-packages (from pandas-profiling) (0.11.2)
# Requirement already satisfied: tqdm<4.65,>=4.48.2 in c:\users\vinis\anaconda3\lib\site-packages (from pandas-profiling) (4.62.3)
# Requirement already satisfied: matplotlib<3.6,>=3.2 in c:\users\vinis\anaconda3\lib\site-packages (from pandas-profiling) (3.4.3)
# Collecting missingno<0.6,>=0.4.2
#   Downloading missingno-0.5.1-py3-none-any.whl (8.7 kB)
# Collecting phik<0.13,>=0.11.1
#   Downloading phik-0.12.2-cp39-cp39-win_amd64.whl (685 kB)
# Collecting tangled-up-in-unicode==0.2.0
#   Downloading tangled_up_in_unicode-0.2.0-py3-none-any.whl (4.7 MB)
# Requirement already satisfied: numpy<1.24,>=1.16.0 in c:\users\vinis\anaconda3\lib\site-packages (from pandas-profiling) (1.20.3)
# Collecting htmlmin==0.1.12
#   Downloading htmlmin-0.1.12.tar.gz (19 kB)
# Collecting visions[type_image_path]==0.7.5
#   Downloading visions-0.7.5-py3-none-any.whl (102 kB)
# Requirement already satisfied: networkx>=2.4 in c:\users\vinis\anaconda3\lib\site-packages (from visions[type_image_path]==0.7.5->pandas-profiling) (2.6.3)
# Requirement already satisfied: attrs>=19.3.0 in c:\users\vinis\anaconda3\lib\site-packages (from visions[type_image_path]==0.7.5->pandas-profiling) (21.2.0)
# Collecting imagehash
#   Downloading ImageHash-4.3.0-py2.py3-none-any.whl (296 kB)
# Requirement already satisfied: Pillow in c:\users\vinis\anaconda3\lib\site-packages (from visions[type_image_path]==0.7.5->pandas-profiling) (8.4.0)
# Requirement already satisfied: MarkupSafe>=0.23 in c:\users\vinis\anaconda3\lib\site-packages (from jinja2<3.2,>=2.11.1->pandas-profiling) (1.1.1)
# Requirement already satisfied: python-dateutil>=2.7 in c:\users\vinis\anaconda3\lib\site-packages (from matplotlib<3.6,>=3.2->pandas-profiling) (2.8.2)
# Requirement already satisfied: pyparsing>=2.2.1 in c:\users\vinis\anaconda3\lib\site-packages (from matplotlib<3.6,>=3.2->pandas-profiling) (3.0.4)
# Requirement already satisfied: cycler>=0.10 in c:\users\vinis\anaconda3\lib\site-packages (from matplotlib<3.6,>=3.2->pandas-profiling) (0.10.0)
# Requirement already satisfied: kiwisolver>=1.0.1 in c:\users\vinis\anaconda3\lib\site-packages (from matplotlib<3.6,>=3.2->pandas-profiling) (1.3.1)
# Requirement already satisfied: six in c:\users\vinis\anaconda3\lib\site-packages (from cycler>=0.10->matplotlib<3.6,>=3.2->pandas-profiling) (1.16.0)
# Requirement already satisfied: pytz>=2017.3 in c:\users\vinis\anaconda3\lib\site-packages (from pandas!=1.4.0,<1.5,>1.1->pandas-profiling) (2021.3)
# Requirement already satisfied: typing-extensions>=3.7.4.3 in c:\users\vinis\anaconda3\lib\site-packages (from pydantic<1.10,>=1.8.1->pandas-profiling) (3.10.0.2)
# Requirement already satisfied: charset-normalizer~=2.0.0 in c:\users\vinis\anaconda3\lib\site-packages (from requests<2.29,>=2.24.0->pandas-profiling) (2.0.4)
# Requirement already satisfied: urllib3<1.27,>=1.21.1 in c:\users\vinis\anaconda3\lib\site-packages (from requests<2.29,>=2.24.0->pandas-profiling) (1.26.7)
# Requirement already satisfied: idna<4,>=2.5 in c:\users\vinis\anaconda3\lib\site-packages (from requests<2.29,>=2.24.0->pandas-profiling) (3.2)
# Requirement already satisfied: certifi>=2017.4.17 in c:\users\vinis\anaconda3\lib\site-packages (from requests<2.29,>=2.24.0->pandas-profiling) (2022.6.15)
# Collecting packaging>=21.3
#   Using cached packaging-21.3-py3-none-any.whl (40 kB)
# Requirement already satisfied: patsy>=0.5.2 in c:\users\vinis\anaconda3\lib\site-packages (from statsmodels<0.14,>=0.13.2->pandas-profiling) (0.5.2)
# Requirement already satisfied: colorama in c:\users\vinis\anaconda3\lib\site-packages (from tqdm<4.65,>=4.48.2->pandas-profiling) (0.4.4)
# Requirement already satisfied: PyWavelets in c:\users\vinis\anaconda3\lib\site-packages (from imagehash->visions[type_image_path]==0.7.5->pandas-profiling) (1.1.1)
# Building wheels for collected packages: htmlmin
#   Building wheel for htmlmin (setup.py): started
#   Building wheel for htmlmin (setup.py): finished with status 'done'
#   Created wheel for htmlmin: filename=htmlmin-0.1.12-py3-none-any.whl size=27098 sha256=e0dc12a28a46070d7e06e869a3a3e290db820972b0671c86f22d74d11ad022d7
#   Stored in directory: c:\users\vinis\appdata\local\pip\cache\wheels\1d\05\04\c6d7d3b66539d9e659ac6dfe81e2d0fd4c1a8316cc5a403300
# Successfully built htmlmin
# Installing collected packages: tangled-up-in-unicode, multimethod, visions, packaging, imagehash, statsmodels, phik, missingno, htmlmin, pandas-profiling
#   Attempting uninstall: packaging
#     Found existing installation: packaging 21.0
#     Uninstalling packaging-21.0:
#       Successfully uninstalled packaging-21.0
#   Attempting uninstall: statsmodels
#     Found existing installation: statsmodels 0.12.2
#     Uninstalling statsmodels-0.12.2:
#       Successfully uninstalled statsmodels-0.12.2
# Successfully installed htmlmin-0.1.12 imagehash-4.3.0 missingno-0.5.1 multimethod-1.8 packaging-21.3 pandas-profiling-3.3.0 phik-0.12.2 statsmodels-0.13.2 tangled-up-in-unicode-0.2.0 visions-0.7.5

# %%
from pandas_profiling import ProfileReport
prof = ProfileReport(df)
prof.to_file(output_file='output.html')
# Out:
# Summarize dataset:   0%|          | 0/5 [00:00<?, ?it/s]
# Generate report structure:   0%|          | 0/1 [00:00<?, ?it/s]
# Render HTML:   0%|          | 0/1 [00:00<?, ?it/s]
# Export report to file:   0%|          | 0/1 [00:00<?, ?it/s]
